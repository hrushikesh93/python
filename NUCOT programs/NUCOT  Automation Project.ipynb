# %%
from datascience import simple_linear_regression,gradient_descent
import pandas as pd
import numpy as np
ms = pd.read_csv('lsd_math_score_data.csv')
ms
# Out:
#    Time_delay  Drug_ppm  Math_score
# 0           5      1.17       78.93
# 1          15      2.97       58.20
# 2          30      3.26       67.47
# 3          60      4.69       37.47
# 4         120      5.83       45.65
# 5         240      6.00       32.92
# 6         480      6.41       29.97

# %%
simple_linear_regression(ms[['Time_delay']],ms[['Drug_ppm']])

# %%
x =  np.linspace(-3, 3, 7)
#x**3+x**2+x+1
#3*x**2+2*x+1
gradient_descent(x,3,0.1,0.001,10)
# Out:
# enter f(x) equation:x**3+x**2+x+1
# enter df(x) equation:3*x**2+2*x+1
